# %%
from qdrant_client import QdrantClient

qdrant_client = QdrantClient(host="localhost", port=6333)

print(qdrant_client.get_collections())
# Out:
# collections=[CollectionDescription(name='china_history'), CollectionDescription(name='law')]

# %%
DENSE_MODEL = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
SPARSE_MODEL = "prithivida/Splade_PP_en_v1"
qdrant_client.set_model(DENSE_MODEL,cache_dir="./embedding_model")
        # comment this line to use dense vectors only
qdrant_client.set_sparse_model(SPARSE_MODEL,cache_dir="./sparse_model")
search_result = qdrant_client.query(
        collection_name='law',
        query_text='敲诈勒索罪',
        query_filter=None,  # If you don't want any filters for now
            )
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[4], line 6
#       2 SPARSE_MODEL = "prithivida/Splade_PP_en_v1"
#       3 # qdrant_client.set_model(DENSE_MODEL,cache_dir="./embedding_model")
#       4 #         # comment this line to use dense vectors only
#       5 # qdrant_client.set_sparse_model(SPARSE_MODEL,cache_dir="./sparse_model")
# ----> 6 search_result = qdrant_client.query(
#       7         collection_name='law',
#       8         query_text='敲诈勒索罪',
#       9         query_filter=None,  # If you don't want any filters for now
#      10             )
#
# File /opt/miniconda3/envs/zyhdl/lib/python3.12/site-packages/qdrant_client/qdrant_fastembed.py:687, in QdrantFastembedMixin.query(self, collection_name, query_text, query_filter, limit, **kwargs)
#     683 query_vector = embeddings[0].tolist()
#     685 if self.sparse_embedding_model_name is None:
#     686     return self._scored_points_to_query_responses(
# --> 687         self.search(
#     688             collection_name=collection_name,
#     689             query_vector=models.NamedVector(
#     690                 name=self.get_vector_field_name(), vector=query_vector
#     691             ),
#     692             query_filter=query_filter,
#     693             limit=limit,
#     694             with_payload=True,
#     695             **kwargs,
#     696         )
#     697     )
#     699 sparse_embedding_model_inst = self._get_or_init_sparse_model(
#     700     model_name=self.sparse_embedding_model_name
#     701 )
#     702 sparse_vector = list(sparse_embedding_model_inst.query_embed(query=query_text))[0]
#
# File /opt/miniconda3/envs/zyhdl/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:387, in QdrantClient.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, append_payload, consistency, shard_key_selector, timeout, **kwargs)
#     316 """Search for closest vectors in collection taking into account filtering conditions
#     317
#     318 Args:
#    (...)
#     383     List of found close points with similarity scores.
#     384 """
#     385 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# --> 387 return self._client.search(
#     388     collection_name=collection_name,
#     389     query_vector=query_vector,
#     390     query_filter=query_filter,
#     391     search_params=search_params,
#     392     limit=limit,
#     393     offset=offset,
#     394     with_payload=with_payload,
#     395     with_vectors=with_vectors,
#     396     score_threshold=score_threshold,
#     397     append_payload=append_payload,
#     398     consistency=consistency,
#     399     shard_key_selector=shard_key_selector,
#     400     timeout=timeout,
#     401     **kwargs,
#     402 )
#
# File /opt/miniconda3/envs/zyhdl/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:563, in QdrantRemote.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, append_payload, consistency, shard_key_selector, timeout, **kwargs)
#     560 if isinstance(with_payload, grpc.WithPayloadSelector):
#     561     with_payload = GrpcToRest.convert_with_payload_selector(with_payload)
# --> 563 search_result = self.http.points_api.search_points(
#     564     collection_name=collection_name,
#     565     consistency=consistency,
#     566     timeout=timeout,
#     567     search_request=models.SearchRequest(
#     568         vector=query_vector,
#     569         filter=query_filter,
#     570         limit=limit,
#     571         offset=offset,
#     572         params=search_params,
#     573         with_vector=with_vectors,
#     574         with_payload=with_payload,
#     575         score_threshold=score_threshold,
#     576         shard_key=shard_key_selector,
#     577     ),
#     578 )
#     579 result: Optional[List[types.ScoredPoint]] = search_result.result
#     580 assert result is not None, "Search returned None"
#
# File /opt/miniconda3/envs/zyhdl/lib/python3.12/site-packages/qdrant_client/http/api/points_api.py:1820, in SyncPointsApi.search_points(self, collection_name, consistency, timeout, search_request)
#    1810 def search_points(
#    1811     self,
#    1812     collection_name: str,
#    (...)
#    1815     search_request: m.SearchRequest = None,
#    1816 ) -> m.InlineResponse20016:
#    1817     """
#    1818     Retrieve closest points based on vector similarity and given filtering conditions
#    1819     """
# -> 1820     return self._build_for_search_points(
#    1821         collection_name=collection_name,
#    1822         consistency=consistency,
#    1823         timeout=timeout,
#    1824         search_request=search_request,
#    1825     )
#
# File /opt/miniconda3/envs/zyhdl/lib/python3.12/site-packages/qdrant_client/http/api/points_api.py:852, in _PointsApi._build_for_search_points(self, collection_name, consistency, timeout, search_request)
#     850 if "Content-Type" not in headers:
#     851     headers["Content-Type"] = "application/json"
# --> 852 return self.api_client.request(
#     853     type_=m.InlineResponse20016,
#     854     method="POST",
#     855     url="/collections/{collection_name}/points/search",
#     856     headers=headers if headers else None,
#     857     path_params=path_params,
#     858     params=query_params,
#     859     content=body,
#     860 )
#
# File /opt/miniconda3/envs/zyhdl/lib/python3.12/site-packages/qdrant_client/http/api_client.py:79, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      77     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      78 request = self._client.build_request(method, url, **kwargs)
# ---> 79 return self.send(request, type_)
#
# File /opt/miniconda3/envs/zyhdl/lib/python3.12/site-packages/qdrant_client/http/api_client.py:102, in ApiClient.send(self, request, type_)
#     100     except ValidationError as e:
#     101         raise ResponseHandlingException(e)
# --> 102 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 400 (Bad Request)
# Raw response content:
# b'{"status":{"error":"Wrong input: Vector with name `fast-bge-small-en` is not configured in this collection, available names: fast-paraphrase-multilingual-minilm-l12-v2, fast-sparse-splade_pp_en_v1" ...'
